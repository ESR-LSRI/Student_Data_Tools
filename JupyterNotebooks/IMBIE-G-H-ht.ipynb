# %% [markdown]
#  Read in an ICESat-2 track and plot
#
# This notebook shows you how to read in two icesat-2 tracks from a CSV file as  dataframed and plots them together
#
# This also provides an example of filtering by beam.
#
#
# written by S. Howard July 9, 2023

# %% [markdown]
# ## Import libaries

# %%
# first we need to import Libaries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Read in files
#
# Now we can read in the data from csv files using pandas

# %%
time = pd.read_csv("ATL15_002_G-H_delta_h_time.csv")
time

height = pd.read_csv("G-H height - Sheet2.csv")
height
# Out:
#     4.53E-01
# 0    0.10700
# 1    0.00676
# 2    0.07280
# 3    0.38200
# 4    0.00000
# 5   -0.09580
# 6    0.17900
# 7    0.10200
# 8   -0.17500
# 9   -0.35000
# 10  -0.43300
# 11  -0.51400
# 12  -0.75800
# 13  -0.82100

# %% [markdown]
# ## Plot all the data

# %%
#Plot all the data.
# Each rgt file has 6 beams

fig = plt.figure(num=None, figsize=(10, 8))

# Plot Track 1 Elevations
ax1 = plt.subplot(111)
ax1.set_title("track422: Elevations: time 1")


ax1.plot(time, height)

# %% [markdown]
# ## Filter by beam (grab 1 beam)

# %%
beam1=data_time1[(data_time1['beam'] == 'gt3r')]
beam1
beam2=data_time2[(data_time2['beam'] == 'gt3r')]
beam2
# Out:
#       segment_id   longitude   latitude       h_li  atl06_quality_summary  \
# 0        1433780  177.870589 -77.275449 -57.416092                      0
# 1        1433781  177.870449 -77.275625 -57.405350                      0
# 2        1433782  177.870308 -77.275800 -57.397670                      0
# 3        1433783  177.870166 -77.275976 -57.398033                      0
# 4        1433784  177.870023 -77.276151 -57.417050                      0
# ...          ...         ...        ...        ...                    ...
# 5662     1439442  177.010203 -78.268196  -5.625409                      0
# 5663     1439443  177.010035 -78.268371  -5.588171                      0
# 5664     1439444  177.009868 -78.268546  -5.566362                      0
# 5665     1439445  177.009701 -78.268721  -5.591361                      0
# 5666     1439446  177.009535 -78.268896  -5.558689                      0
#
#       track_id  beam                                          file_name
# 0          442  gt3r  processed_ATL06_20220720211931_04421610_005_01.h5
# 1          442  gt3r  processed_ATL06_20220720211931_04421610_005_01.h5
# 2          442  gt3r  processed_ATL06_20220720211931_04421610_005_01.h5
# 3          442  gt3r  processed_ATL06_20220720211931_04421610_005_01.h5
# 4          442  gt3r  processed_ATL06_20220720211931_04421610_005_01.h5
# ...        ...   ...                                                ...
# 5662       442  gt3r  processed_ATL06_20220720211931_04421610_005_01.h5
# 5663       442  gt3r  processed_ATL06_20220720211931_04421610_005_01.h5
# 5664       442  gt3r  processed_ATL06_20220720211931_04421610_005_01.h5
# 5665       442  gt3r  processed_ATL06_20220720211931_04421610_005_01.h5
# 5666       442  gt3r  processed_ATL06_20220720211931_04421610_005_01.h5
#
# [5667 rows x 8 columns]

# %%
## plot this singlebeam

fig = plt.figure(num=None, figsize=(10, 8))

# Plot Track 1 Elevations
ax1 = plt.subplot(111)
ax1.set_title("track422: Elevations: time 1, beam1")


ax1.plot(beam1["latitude"].values, beam1["h_li"].values, '.', linewidth=1.0, color='r')

ax1.plot(beam2["latitude"].values, beam2["h_li"].values, '.', linewidth=1.0, color='b')

ax1.set_xlim([-77.8, -77.6  ])
ax1.set_ylim([-60, 0])
# Out:
# (-60.0, 0.0)
